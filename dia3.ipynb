# %%
print('hola')
# Out:
# hola

# %%
def saludar ():
    print("hola")

saludar()
# Out:
# hola

# %%
#Definir la variable llamada palabra
#Crear una funcion def imprimir_palabra
    #imprimir la variable palabra
#llamar a la funcion
palabra = "Hola"

def imprimir_palabra():
    print(palabra)
    
imprimir_palabra()
# Out:
# Hola

# %%
#definimos la funcion que sume 2 numeros:
#definimos 2 variabes con input

numero1 =int(input("Ingrese el primer numero"))
numero2 =int(input("Ingrese el segundo numero"))

def sumar (n1, n2):
    print(n1 + n2)
sumar(numero1, numero2)

# %%
#crear variables

letra1 = input("ingrese una letra")
letra2 = input("ingrese una letra")

def verificar_letras (l1, l2):
    if l1 == l2:
        print("las dos letras son iguales")
    else:
        print("las letras son diferentes")

verificar_letras(letra1, letra2)
# Out:
# las dos letras son iguales

# %% [markdown]
# # Return

# %%
def sumar (n1, n2):
    resultado_suma= n1 + n2
    return resultado_suma
sumar(numero1, numero2)

# %% [markdown]
# # Challenge 3 🤺 - 15m
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# Pista: cantidad de letras de una palabra en python

# %%
#Creamos una funcion que reciba DOS PARAMETROS (Una palabra y UN numero)

palabra = input("ingrese una palabra")
numero = int(input("ingrese un numero"))

def palabra_numero(palabra, numero):
    if len(palabra) == numero:
        return True
    else:
        return False
        

palabra_numero(palabra, numero)
# Out:
# False

# %% [markdown]
# ## Challenge 4 🤺 - 20 min
# Crear función que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre corchetes []. De lo contrario, retornar solo la letra.

# %%
#definimos las variables

palabra = input("Ingrese una palabra")
letra = "o"

#definimos la funcion

def letra_en_palabra(p, l):
    if l in p:
        return [l]
    else:
        return l
    
letra_en_palabra(palabra, letra)
# Out:
# ['o']

# %% [markdown]
# ### Challenge 5 🤺 - 20m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
#  ### Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  ### Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %%
# definimos la variable de la palabra a ingresar
palabras_ingresadas = []
for i in range(3):
    palabra = input("Ingrese una palabra")
    lista_de_palabras=list(palabra)
    palabras_ingresadas.append(lista_de_palabras)
    print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['n', 'a', 'r', 'a', 'n', 'j', 'a']]
# [['h', 'o', 'l', 'a'], ['n', 'a', 'r', 'a', 'n', 'j', 'a'], ['m', 'a', 'n', 'z', 'a', 'n', 'a']]

# %% [markdown]
# ### Challenge 6 🤺 - 20m
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ### ['h', 'o', 'l', 'i', 's']
# #### ['h', 'e', 'l', 'l', 'o']
# ### ['h', 'a', 'l', 'l', 'o']

# %%
#definimos la lista a ser imprimida
lista= [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#definimos la funcion

def grilla():
    print(lista[0])
    print(lista[1])
    print(lista[2])   

grilla()
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
#lista de Letras Verificadas
letras_verificadas= []
cantidad_letras = 5

def verificador_palabra(palabras_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabras_ingresada[i] == palabra_secreta[i] #True o False
        la_letra_existe_en_la_palabra = palabras_ingresada[i] in palabra_secreta

        if las_palabras_son_iguales:
            letras_verificadas.append("[", palabras_ingresada, "]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append("(", palabras_ingresada, ")")
        else: 
            letras_verificadas.append(palabras_ingresada[i])

    return letras_verificadas
verificador_palabra()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 18
#      15             letras_verificadas.append(palabras_ingresada[i])
#      17     return letras_verificadas
# ---> 18 verificador_palabra('holas', 'calor')
#
# Cell In[21], line 7, in verificador_palabra(palabras_ingresada, palabra_secreta)
#       5 def verificador_palabra(palabras_ingresada, palabra_secreta):
#       6     for i in palabras_ingresada:
# ----> 7         las_palabras_son_iguales = palabras_ingresada[i] == palabra_secreta[i] #True o False
#       8         la_letra_existe_en_la_palabra = palabras_ingresada[i] in palabra_secreta
#      10         if las_palabras_son_iguales:
#
# TypeError: string indices must be integers, not 'str'
